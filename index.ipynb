# %% [markdown]
# # One-to-Many and Many-to-Many Joins
#
# ## Introduction
#
# Previously, you've learned about the typical case where one joins on a primary or foreign key. In this section, you'll explore other types of joins using One-to-Many and Many-to-many relationships!
#
# ## Objectives
#
# You will be able to:
#
# * Explain one-to-many and many-to-many joins as well as implications for the size of query results
#
# ## One-to-Many and Many-to-Many relationships
#
# So far, you've seen a couple of different kinds of join statements: left joins and inner joins. Both of these refer to the way in which you would like to define your joins based on the tables and their shared information. Another perspective on this is the number of matches between the tables based on your defined links with the keywords *on* or *using*.
#
# You have also seen the typical case where one joins on a primary or foreign key. For example, when you join on customerID or employeeID, this value should be unique to that table. As such, your joins have been very similar to using a dictionary to find additional information associated with that record. In cases where there are multiple entries, in either table, for the field you are joining on, you will similarly be given multiple rows in your resulting view, one for each of these entries.
#
# For example, let's say you have another table 'restaurants' that has many columns including *name*, *city*, and *rating*. If you were to join this table with the offices table using the shared city column, you might get some unexpected behavior. That is, in the office table, there is only one office per city. However, because there is apt to be more than one restaurant for each of these cities in your second table, you will get unique combinations of Offices and Restaurants from your join. If there are 513 restaurants for Boston in your restaurant table and 1 office for Boston, your joined table will have each of these 513 rows, one for each restaurant along with the one office.
#
# If you had 2 offices for Boston, and 513 restaurants, your join would have 1026 rows for Boston; 513 for each restaurant along with the first office and 513 for each restaurant with the second office. Three offices in Boston would similarly produce 1539 rows; one for each unique combination of restaurants and offices. This is where you should be particularly careful of many to many joins as the resulting set size can explode drastically potentially consuming vast amounts of memory and other resources.
#
# <img src='images/Database-Schema.png' width=550>
#
# ## Connecting to the Database

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Checking Sizes of Resulting Joins...

# %% [markdown]
# ### The original tables...

# %%
cur.execute('select * from offices;')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 8
#   officeCode           city            phone              addressLine1  \
# 0          1  San Francisco  +1 650 219 4782         100 Market Street
# 1          2         Boston  +1 215 837 0825          1550 Court Place
# 2          3            NYC  +1 212 555 3000      523 East 53rd Street
# 3          4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo  +81 33 224 5000               4-1 Kioicho
#
#   addressLine2       state country postalCode territory
# 0    Suite 300          CA     USA      94080        NA
# 1    Suite 102          MA     USA      02107        NA
# 2      apt. 5A          NY     USA      10022        NA
# 3                           France      75017      EMEA
# 4               Chiyoda-Ku   Japan   102-8578     Japan

# %%
cur.execute('select * from employees;')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 23
#   employeeNumber   lastName firstName extension  \
# 0           1002     Murphy     Diane     x5800
# 1           1056  Patterson      Mary     x4611
# 2           1076   Firrelli      Jeff     x9273
# 3           1088  Patterson   William     x4871
# 4           1102     Bondur    Gerard     x5408
#
#                              email officeCode reportsTo              jobTitle
# 0     dmurphy@classicmodelcars.com          1                       President
# 1   mpatterso@classicmodelcars.com          1      1002              VP Sales
# 2   jfirrelli@classicmodelcars.com          1      1002          VP Marketing
# 3  wpatterson@classicmodelcars.com          6      1056  Sales Manager (APAC)
# 4     gbondur@classicmodelcars.com          4      1056   Sale Manager (EMEA)

# %% [markdown]
# ### A One-to-One Join...

# %%
cur.execute('select * from offices join employees using(officeCode);')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 23
#   officeCode           city            phone       addressLine1 addressLine2  \
# 0          1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
# 1          1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
# 2          1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
# 3          1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
# 4          1  San Francisco  +1 650 219 4782  100 Market Street    Suite 300
#
#   state country postalCode territory employeeNumber   lastName firstName  \
# 0    CA     USA      94080        NA           1002     Murphy     Diane
# 1    CA     USA      94080        NA           1056  Patterson      Mary
# 2    CA     USA      94080        NA           1076   Firrelli      Jeff
# 3    CA     USA      94080        NA           1143        Bow   Anthony
# 4    CA     USA      94080        NA           1165   Jennings    Leslie
#
#   extension                           email reportsTo            jobTitle
# 0     x5800    dmurphy@classicmodelcars.com                     President
# 1     x4611  mpatterso@classicmodelcars.com      1002            VP Sales
# 2     x9273  jfirrelli@classicmodelcars.com      1002        VP Marketing
# 3     x5428       abow@classicmodelcars.com      1056  Sales Manager (NA)
# 4     x3291  ljennings@classicmodelcars.com      1143           Sales Rep

# %% [markdown]
# ### A One-to-Many Join
# Here you join products with product lines. There are only a few product lines that will be matched to each product. As a result, the product line descriptions will be repeated in your resulting view.

# %%
cur.execute('select * from products;')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 110
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  Turnable front wheels; steering function; deta...            7305    98.58
# 2  Official Moto Guzzi logos and insignias, saddl...            6625    68.99
# 3  Model features, official Harley Davidson logos...            5582    91.02
# 4  Features include: Turnable front wheels; steer...            3252    85.68
#
#      MSRP
# 0   95.70
# 1  214.30
# 2  118.94
# 3  193.66
# 4  136.00

# %%
cur.execute('select * from productlines;')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 7
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1   Motorcycles  Our motorcycles are state of the art replicas ...
# 2        Planes  Unique, diecast airplane and helicopter replic...
# 3         Ships  The perfect holiday or anniversary gift for ex...
# 4        Trains  Model trains are a rewarding hobby for enthusi...
#
#   htmlDescription image
# 0
# 1
# 2
# 3
# 4

# %%
cur.execute("""select * from products
                      join productlines
                      using(productLine);""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df.head()
# Out:
# Number of results: 110
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  Turnable front wheels; steering function; deta...            7305    98.58
# 2  Official Moto Guzzi logos and insignias, saddl...            6625    68.99
# 3  Model features, official Harley Davidson logos...            5582    91.02
# 4  Features include: Turnable front wheels; steer...            3252    85.68
#
#      MSRP                                    textDescription htmlDescription  \
# 0   95.70  Our motorcycles are state of the art replicas ...
# 1  214.30  Attention car enthusiasts: Make your wildest c...
# 2  118.94  Our motorcycles are state of the art replicas ...
# 3  193.66  Our motorcycles are state of the art replicas ...
# 4  136.00  Attention car enthusiasts: Make your wildest c...
#
#   image
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### A Many-to-Many Join
#
# A many-to-many join is as it sounds; there are multiple entries for the shared field in both tables. While somewhat contrived, we can see this through the example below, joining the offices and customers table based on the state field. For example, there are 2 offices in MA and 9 customers in MA. Joining the two tables by state will result in 18 rows associated with MA; one for each customer combined with the first office, and then another for each customer combined with the second option. This is not a particularly useful join without applying some additional aggregations or pivots, but can also demonstrate how a poorly written query can go wrong. For example, if there are a large number of occurences in both tables, such as tens of thousands, then a many-to-many join could result in billions of resulting rows. Such ill conceived joins can cause severe load can be put on the database causing slow execution time, and potentially even tying up database resources for other analysts who may be using the system.

# %%
cur.execute("""select * from offices
                        join customers
                        using(state);""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print('Number of results:', len(df))
df
# Out:
# Number of results: 254
#     officeCode           city             phone              addressLine1  \
# 0            1  San Francisco   +1 650 219 4782         100 Market Street
# 1            1  San Francisco   +1 650 219 4782         100 Market Street
# 2            1  San Francisco   +1 650 219 4782         100 Market Street
# 3            1  San Francisco   +1 650 219 4782         100 Market Street
# 4            1  San Francisco   +1 650 219 4782         100 Market Street
# 5            1  San Francisco   +1 650 219 4782         100 Market Street
# 6            1  San Francisco   +1 650 219 4782         100 Market Street
# 7            1  San Francisco   +1 650 219 4782         100 Market Street
# 8            1  San Francisco   +1 650 219 4782         100 Market Street
# 9            1  San Francisco   +1 650 219 4782         100 Market Street
# 10           1  San Francisco   +1 650 219 4782         100 Market Street
# 11           2         Boston   +1 215 837 0825          1550 Court Place
# 12           2         Boston   +1 215 837 0825          1550 Court Place
# 13           2         Boston   +1 215 837 0825          1550 Court Place
# 14           2         Boston   +1 215 837 0825          1550 Court Place
# 15           2         Boston   +1 215 837 0825          1550 Court Place
# 16           2         Boston   +1 215 837 0825          1550 Court Place
# 17           2         Boston   +1 215 837 0825          1550 Court Place
# 18           2         Boston   +1 215 837 0825          1550 Court Place
# 19           2         Boston   +1 215 837 0825          1550 Court Place
# 20           3            NYC   +1 212 555 3000      523 East 53rd Street
# 21           3            NYC   +1 212 555 3000      523 East 53rd Street
# 22           3            NYC   +1 212 555 3000      523 East 53rd Street
# 23           3            NYC   +1 212 555 3000      523 East 53rd Street
# 24           3            NYC   +1 212 555 3000      523 East 53rd Street
# 25           3            NYC   +1 212 555 3000      523 East 53rd Street
# 26           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 27           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 28           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 29           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# ..         ...            ...               ...                       ...
# 224          7         London  +44 20 7877 2041       25 Old Broad Street
# 225          7         London  +44 20 7877 2041       25 Old Broad Street
# 226          7         London  +44 20 7877 2041       25 Old Broad Street
# 227          7         London  +44 20 7877 2041       25 Old Broad Street
# 228          7         London  +44 20 7877 2041       25 Old Broad Street
# 229          7         London  +44 20 7877 2041       25 Old Broad Street
# 230          7         London  +44 20 7877 2041       25 Old Broad Street
# 231          7         London  +44 20 7877 2041       25 Old Broad Street
# 232          7         London  +44 20 7877 2041       25 Old Broad Street
# 233          7         London  +44 20 7877 2041       25 Old Broad Street
# 234          7         London  +44 20 7877 2041       25 Old Broad Street
# 235          7         London  +44 20 7877 2041       25 Old Broad Street
# 236          7         London  +44 20 7877 2041       25 Old Broad Street
# 237          7         London  +44 20 7877 2041       25 Old Broad Street
# 238          7         London  +44 20 7877 2041       25 Old Broad Street
# 239          7         London  +44 20 7877 2041       25 Old Broad Street
# 240          7         London  +44 20 7877 2041       25 Old Broad Street
# 241          7         London  +44 20 7877 2041       25 Old Broad Street
# 242          7         London  +44 20 7877 2041       25 Old Broad Street
# 243          7         London  +44 20 7877 2041       25 Old Broad Street
# 244          7         London  +44 20 7877 2041       25 Old Broad Street
# 245         27         Boston   +1 977 299 8345      105 Cambridge Street
# 246         27         Boston   +1 977 299 8345      105 Cambridge Street
# 247         27         Boston   +1 977 299 8345      105 Cambridge Street
# 248         27         Boston   +1 977 299 8345      105 Cambridge Street
# 249         27         Boston   +1 977 299 8345      105 Cambridge Street
# 250         27         Boston   +1 977 299 8345      105 Cambridge Street
# 251         27         Boston   +1 977 299 8345      105 Cambridge Street
# 252         27         Boston   +1 977 299 8345      105 Cambridge Street
# 253         27         Boston   +1 977 299 8345      105 Cambridge Street
#
#     addressLine2 state country postalCode territory customerNumber  \
# 0      Suite 300    CA     USA      94080        NA            124
# 1      Suite 300    CA     USA      94080        NA            129
# 2      Suite 300    CA     USA      94080        NA            161
# 3      Suite 300    CA     USA      94080        NA            205
# 4      Suite 300    CA     USA      94080        NA            219
# 5      Suite 300    CA     USA      94080        NA            239
# 6      Suite 300    CA     USA      94080        NA            321
# 7      Suite 300    CA     USA      94080        NA            347
# 8      Suite 300    CA     USA      94080        NA            450
# 9      Suite 300    CA     USA      94080        NA            475
# 10     Suite 300    CA     USA      94080        NA            487
# 11     Suite 102    MA     USA      02107        NA            173
# 12     Suite 102    MA     USA      02107        NA            198
# 13     Suite 102    MA     USA      02107        NA            204
# 14     Suite 102    MA     USA      02107        NA            286
# 15     Suite 102    MA     USA      02107        NA            320
# 16     Suite 102    MA     USA      02107        NA            362
# 17     Suite 102    MA     USA      02107        NA            379
# 18     Suite 102    MA     USA      02107        NA            462
# 19     Suite 102    MA     USA      02107        NA            495
# 20       apt. 5A    NY     USA      10022        NA            131
# 21       apt. 5A    NY     USA      10022        NA            151
# 22       apt. 5A    NY     USA      10022        NA            181
# 23       apt. 5A    NY     USA      10022        NA            319
# 24       apt. 5A    NY     USA      10022        NA            424
# 25       apt. 5A    NY     USA      10022        NA            456
# 26                      France      75017      EMEA            103
# 27                      France      75017      EMEA            119
# 28                      France      75017      EMEA            121
# 29                      France      75017      EMEA            125
# ..           ...   ...     ...        ...       ...            ...
# 224      Level 7            UK   EC2N 1HN      EMEA            381
# 225      Level 7            UK   EC2N 1HN      EMEA            382
# 226      Level 7            UK   EC2N 1HN      EMEA            385
# 227      Level 7            UK   EC2N 1HN      EMEA            386
# 228      Level 7            UK   EC2N 1HN      EMEA            406
# 229      Level 7            UK   EC2N 1HN      EMEA            409
# 230      Level 7            UK   EC2N 1HN      EMEA            412
# 231      Level 7            UK   EC2N 1HN      EMEA            415
# 232      Level 7            UK   EC2N 1HN      EMEA            443
# 233      Level 7            UK   EC2N 1HN      EMEA            448
# 234      Level 7            UK   EC2N 1HN      EMEA            452
# 235      Level 7            UK   EC2N 1HN      EMEA            458
# 236      Level 7            UK   EC2N 1HN      EMEA            459
# 237      Level 7            UK   EC2N 1HN      EMEA            465
# 238      Level 7            UK   EC2N 1HN      EMEA            473
# 239      Level 7            UK   EC2N 1HN      EMEA            477
# 240      Level 7            UK   EC2N 1HN      EMEA            480
# 241      Level 7            UK   EC2N 1HN      EMEA            481
# 242      Level 7            UK   EC2N 1HN      EMEA            484
# 243      Level 7            UK   EC2N 1HN      EMEA            489
# 244      Level 7            UK   EC2N 1HN      EMEA            496
# 245                 MA     USA      02331        NA            173
# 246                 MA     USA      02331        NA            198
# 247                 MA     USA      02331        NA            204
# 248                 MA     USA      02331        NA            286
# 249                 MA     USA      02331        NA            320
# 250                 MA     USA      02331        NA            362
# 251                 MA     USA      02331        NA            379
# 252                 MA     USA      02331        NA            462
# 253                 MA     USA      02331        NA            495
#
#         ...      contactLastName contactFirstName               phone  \
# 0       ...               Nelson            Susan          4155551450
# 1       ...               Murphy            Julie          6505555787
# 2       ...            Hashimoto             Juri          6505556809
# 3       ...                Young            Julie          6265557265
# 4       ...                Young             Mary          3105552373
# 5       ...             Thompson          Valarie          7605558146
# 6       ...                Brown            Julie          6505551386
# 7       ...             Chandler            Brian          2155554369
# 8       ...                Frick              Sue          4085553659
# 9       ...             Thompson            Steve          3105553722
# 10      ...               Taylor              Sue          4155554312
# 11      ...                Tseng            Jerry          6175555555
# 12      ...               Taylor           Leslie          6175558428
# 13      ...              Barajas           Miguel          6175557555
# 14      ...            Hernandez            Marta          6175558555
# 15      ...                Huang             Wing          5085559555
# 16      ...              Yoshido             Juri          6175559555
# 17      ...               Nelson            Allen          6175558555
# 18      ...              Benitez          Violeta          5085552555
# 19      ...               Franco          Valarie          6175552555
# 20      ...                  Lee             Kwai          2125557818
# 21      ...                Young             Jeff          2125557413
# 22      ...                Frick          Michael          2125551500
# 23      ...                Frick            Steve          9145554562
# 24      ...            Hernandez            Maria          2125558493
# 25      ...                 Choi               Yu          2125551957
# 26      ...              Schmitt          Carine           40.32.2555
# 27      ...              Labrune          Janine           40.67.8555
# 28      ...           Bergulfsen           Jonas           07-98 9555
# 29      ...      Piestrzeniewicz         Zbyszek        (26) 642-7555
# ..      ...                  ...              ...                 ...
# 224     ...             Cartrain         Pascale     (071) 23 67 2555
# 225     ...                Pipps           Georg            6562-9555
# 226     ...                 Cruz           Arnold      +63 2 555 3587
# 227     ...               Moroni        Maurizio          0522-556555
# 228     ...              Perrier        Dominique      (1) 47.55.6555
# 229     ...               Müller            Rita          0711-555361
# 230     ...                McRoy            Sarah         04 499 9555
# 231     ...          Donnermeyer          Michael   +49 89 61 08 9555
# 232     ...                Feuer       Alexander          0342-555176
# 233     ...              Larsson           Martha        0695-34 6555
# 234     ...               Mendel          Roland            7675-3555
# 235     ...               Sommer          Martín       (91) 555 22 82
# 236     ...              Ottlieb            Sven          0241-039123
# 237     ...                Anton           Carmen      +34 913 728555
# 238     ...              Ricotti           Franco       +39 022515555
# 239     ...                 Moos           Hanna           0621-08555
# 240     ...              Semenov       Alexander      +7 812 293 0521
# 241     ...          Altagar,G M           Raanan    + 972 9 959 8555
# 242     ...                 Roel      José Pedro       (95) 555 82 82
# 243     ...                Smith          Thomas       (171) 555-7555
# 244     ...              Snowden             Tony       +64 9 5555500
# 245     ...                Tseng            Jerry          6175555555
# 246     ...               Taylor           Leslie          6175558428
# 247     ...              Barajas           Miguel          6175557555
# 248     ...            Hernandez            Marta          6175558555
# 249     ...                Huang             Wing          5085559555
# 250     ...              Yoshido             Juri          6175559555
# 251     ...               Nelson            Allen          6175558555
# 252     ...              Benitez          Violeta          5085552555
# 253     ...               Franco          Valarie          6175552555
#
#                          addressLine1           addressLine2  \
# 0                     5677 Strong St.
# 1           5557 North Pendale Street
# 2                   9408 Furth Circle
# 3                  78934 Hillside Dr.
# 4                    4097 Douglas Av.
# 5                    361 Furth Circle
# 6                     7734 Strong St.
# 7                    6047 Douglas Av.
# 8                      3086 Ingle Ln.
# 9                   3675 Furth Circle
# 10                  2793 Furth Circle
# 11                     4658 Baden Av.
# 12                  16780 Pompton St.
# 13                 7635 Spinnaker Dr.
# 14                39323 Spinnaker Dr.
# 15                  4575 Hillside Dr.
# 16                 8616 Spinnaker Dr.
# 17                   7825 Douglas Av.
# 18                  1785 First Street
# 19                     6251 Ingle Ln.
# 20            897 Long Airport Avenue
# 21                  4092 Furth Circle              Suite 400
# 22                  2678 Kingston Rd.              Suite 101
# 23          3758 North Pendale Street
# 24                   5905 Pompton St.              Suite 750
# 25          5290 North Pendale Street              Suite 200
# 26                     54, rue Royale
# 27       67, rue des Cinquante Otages
# 28             Erling Skakkes gate 78
# 29                    ul. Filtrowa 68
# ..                                ...                    ...
# 224              Boulevard Tirou, 255
# 225                       Geislweg 14
# 226                15 McCallum Street  NatWest Center #13-03
# 227            Strada Provinciale 124
# 228                 25, rue Lauriston
# 229                 Adenauerallee 900
# 230                  101 Lambton Quay               Level 11
# 231                      Hansastr. 15
# 232                       Heerstr. 22
# 233                      Åkergatan 24
# 234                      Kirchgasse 6
# 235                    C/ Araquil, 67
# 236                      Walserweg 21
# 237  c/ Gobelas, 19-1 Urb. La Florida
# 238             20093 Cologno Monzese    Alessandro Volta 16
# 239                    Forsterstr. 57
# 240                   2 Pobedy Square
# 241                    3 Hagalim Blv.
# 242                     C/ Romero, 33
# 243                   120 Hanover Sq.
# 244                Arenales 1938 3'A'
# 245                    4658 Baden Av.
# 246                 16780 Pompton St.
# 247                7635 Spinnaker Dr.
# 248               39323 Spinnaker Dr.
# 249                 4575 Hillside Dr.
# 250                8616 Spinnaker Dr.
# 251                  7825 Douglas Av.
# 252                 1785 First Street
# 253                    6251 Ingle Ln.
#
#                  city postalCode      country salesRepEmployeeNumber  \
# 0          San Rafael      97562          USA                   1165
# 1       San Francisco      94217          USA                   1165
# 2          Burlingame      94217          USA                   1165
# 3            Pasadena      90003          USA                   1166
# 4            Glendale      92561          USA                   1166
# 5           San Diego      91217          USA                   1166
# 6       San Francisco      94217          USA                   1165
# 7         Los Angeles      91003          USA                   1166
# 8            San Jose      94217          USA                   1165
# 9             Burbank      94019          USA                   1166
# 10           Brisbane      94217          USA                   1165
# 11          Cambridge      51247          USA                   1188
# 12         Brickhaven      58339          USA                   1216
# 13         Brickhaven      58339          USA                   1188
# 14          Cambridge      51247          USA                   1216
# 15        New Bedford      50553          USA                   1188
# 16             Boston      51003          USA                   1216
# 17         Brickhaven      58339          USA                   1188
# 18        New Bedford      50553          USA                   1216
# 19             Boston      51003          USA                   1188
# 20                NYC      10022          USA                   1323
# 21                NYC      10022          USA                   1286
# 22                NYC      10022          USA                   1286
# 23       White Plains      24067          USA                   1323
# 24                NYC      10022          USA                   1286
# 25                NYC      10022          USA                   1286
# 26             Nantes      44000       France                   1370
# 27             Nantes      44000       France                   1370
# 28            Stavern       4110       Norway                   1504
# 29           Warszawa     01-012       Poland
# ..                ...        ...          ...                    ...
# 224         Charleroi     B-6000      Belgium                   1401
# 225          Salzburg       5020      Austria                   1401
# 226       Makati City    1227 MM  Philippines                   1621
# 227     Reggio Emilia      42100        Italy                   1401
# 228             Paris      75016       France                   1337
# 229         Stuttgart      70563      Germany
# 230        Wellington             New Zealand                   1612
# 231            Munich      80686      Germany                   1504
# 232           Leipzig      04179      Germany
# 233            Bräcke   S-844 67       Sweden                   1504
# 234              Graz       8010      Austria                   1401
# 235            Madrid      28023        Spain                   1702
# 236            Aachen      52066      Germany
# 237            Madrid      28023        Spain
# 238             Milan                   Italy                   1401
# 239          Mannheim      68306      Germany
# 240  Saint Petersburg     196143       Russia
# 241           Herzlia      47625       Israel
# 242           Sevilla      41101        Spain                   1702
# 243            London    WA1 1DP           UK                   1501
# 244        Auckland               New Zealand                   1612
# 245         Cambridge      51247          USA                   1188
# 246        Brickhaven      58339          USA                   1216
# 247        Brickhaven      58339          USA                   1188
# 248         Cambridge      51247          USA                   1216
# 249       New Bedford      50553          USA                   1188
# 250            Boston      51003          USA                   1216
# 251        Brickhaven      58339          USA                   1188
# 252       New Bedford      50553          USA                   1216
# 253            Boston      51003          USA                   1188
#
#     creditLimit
# 0     210500.00
# 1      64600.00
# 2      84600.00
# 3      90700.00
# 4      11000.00
# 5     105000.00
# 6     105000.00
# 7      57700.00
# 8      77600.00
# 9      55400.00
# 10     60300.00
# 11     43400.00
# 12     23000.00
# 13     68700.00
# 14    123700.00
# 15     94500.00
# 16     41900.00
# 17     70700.00
# 18     85800.00
# 19     85100.00
# 20    114900.00
# 21    138500.00
# 22     76400.00
# 23    102700.00
# 24     67500.00
# 25     39800.00
# 26     21000.00
# 27    118200.00
# 28     81700.00
# 29         0.00
# ..          ...
# 224    23500.00
# 225    71700.00
# 226    81500.00
# 227   121400.00
# 228    95000.00
# 229        0.00
# 230    86800.00
# 231    77000.00
# 232        0.00
# 233   116400.00
# 234    45300.00
# 235   104600.00
# 236        0.00
# 237        0.00
# 238    34800.00
# 239        0.00
# 240        0.00
# 241        0.00
# 242    65700.00
# 243    43300.00
# 244   110000.00
# 245    43400.00
# 246    23000.00
# 247    68700.00
# 248   123700.00
# 249    94500.00
# 250    41900.00
# 251    70700.00
# 252    85800.00
# 253    85100.00
#
# [254 rows x 21 columns]

# %%
len(df[df.state=='MA'])
# Out:
# 18

# %% [markdown]
# ## Summary

# %% [markdown]
# In this section, you expanded your join knowledge to One-to-Many and Many-to-many joins!
